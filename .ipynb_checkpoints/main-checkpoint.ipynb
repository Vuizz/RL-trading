# %%
# !pip install finta
# Out:
# Collecting finta
#   Downloading finta-1.3-py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from finta) (1.4.2)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from finta) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->finta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->finta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->finta) (1.16.0)
# Installing collected packages: finta
# Successfully installed finta-1.3

# %%
import yfinance as yf
import pandas as pd
import gym
import gym_anytrading
import numpy as np
import matplotlib.pyplot as plt
from finta import TA
from gym_anytrading.envs import StocksEnv

from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [58], in <cell line: 10>()
#       7 from finta import TA
#       8 from gym_anytrading.envs import StocksEnv
# ---> 10 from stable_baselines.common.vec_env import DummyVecEnv
#      11 from stable_baselines import A2C
#
# File ~\anaconda3\lib\site-packages\stable_baselines\__init__.py:7, in <module>
#       5 from stable_baselines.acer import ACER
#       6 from stable_baselines.acktr import ACKTR
# ----> 7 from stable_baselines.deepq import DQN
#       8 from stable_baselines.her import HER
#       9 from stable_baselines.ppo2 import PPO2
#
# File ~\anaconda3\lib\site-packages\stable_baselines\deepq\__init__.py:1, in <module>
# ----> 1 from stable_baselines.deepq.policies import MlpPolicy, CnnPolicy, LnMlpPolicy, LnCnnPolicy
#       2 from stable_baselines.deepq.build_graph import build_act, build_train  # noqa
#       3 from stable_baselines.deepq.dqn import DQN
#
# File ~\anaconda3\lib\site-packages\stable_baselines\deepq\policies.py:2, in <module>
#       1 import tensorflow as tf
# ----> 2 import tensorflow.contrib.layers as tf_layers
#       3 import numpy as np
#       4 from gym.spaces import Discrete
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
df = yf.download('BTC-USD',start='2021-01-01', end='2022-01-01', interval='1d')

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
#
#                Adj Close       Volume
# Date
# 2021-01-01  29374.152344  40730301359
# 2021-01-02  32127.267578  67865420765
# 2021-01-03  32782.023438  78665235202
# 2021-01-04  31971.914062  81163475344
# 2021-01-05  33992.429688  67547324782

# %%
# Basic environement to test
window = 25
env = gym.make('stocks-v0', df=df, frame_bound=(window,250), window_size=window)

state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:31: UserWarning: WARN: A Box observation space has an unconventional shape (neither an image, nor a 1D vector). We recommend flattening the observation to have only a 1D vector or use a custom policy to properly process the data. Actual observation shape: (25, 2)
#   logger.warn(
# C:\Users\USER\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# C:\Users\USER\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# C:\Users\USER\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'numpy.ndarray'>`
#   logger.warn(
# C:\Users\USER\anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# info {'total_reward': 28110.775390625, 'total_profit': 0.7094600648771283, 'position': 1}

# %%
# Add Indicators

df['RSI'] = TA.RSI(df, 14)
df['ADX'] = TA.ADX(df, 14)
df['BB_W'] = TA.BBWIDTH(df, 30)

df.dropna(inplace=True)

# %%
def add_signals(env):
    start = env.frame_bound[0] - env.window_size
    end = env.frame_bound[1]
    prices = env.df.loc[:, 'Low'].to_numpy()[start:end]
    signal_features = env.df.loc[:, ['Low', 'ADX','BB_W', 'RSI']].to_numpy()[start:end]
    return prices, signal_features

# %%
class MyCustomEnv(StocksEnv):
    _process_data = add_signals
    
env2 = MyCustomEnv(df=df, window_size=10, frame_bound=(10,80))

# %%
env_maker = lambda: env2
env = DummyVecEnv([env_maker])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 2>()
#       1 env_maker = lambda: env2
# ----> 2 env = DummyVecEnv([env_maker])
#
# NameError: name 'DummyVecEnv' is not defined

# %%
model = A2C('MlpLstmPolicy', env, verbose=1) 
model.learn(total_timesteps=1000000)
